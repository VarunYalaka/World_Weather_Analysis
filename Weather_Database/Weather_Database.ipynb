# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90, high=90, size =2000) 
lngs = np.random.uniform(low = -180, high=180, size =2000) 

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates =  list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 745

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(3)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]    
        city_weather_description = city_weather["weather"][0]["description"] 
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into the city_data list
        city_data.append({ "City":city.title(),
                           "Lat": city_lat,
                           "Lng": city_lng,
                           "Max Temp": city_max_temp,
                           "Humidity": city_humidity,
                           "Cloudiness": city_clouds,
                           "Wind Speed": city_wind,
                           "Country": city_country,
                           "Current Description": city_weather_description,
                           "Date": city_date}) 
            
        
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | touros
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | aswan
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | mumford
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | qunduz
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 1 | saint george
# Processing Record 15 of Set 1 | jumla
# Processing Record 16 of Set 1 | norman wells
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | cukai
# Processing Record 23 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | hasaki
# Processing Record 28 of Set 1 | richards bay
# Processing Record 29 of Set 1 | panzhihua
# Processing Record 30 of Set 1 | faanui
# Processing Record 31 of Set 1 | taltal
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | ahipara
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | nhamunda
# Processing Record 37 of Set 1 | oktyabrskoye
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | omagh
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | khambhat
# Processing Record 42 of Set 1 | sao filipe
# Processing Record 43 of Set 1 | xining
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | quatre cocos
# Processing Record 46 of Set 1 | salta
# Processing Record 47 of Set 1 | ca mau
# Processing Record 48 of Set 1 | tautira
# Processing Record 49 of Set 1 | am timan
# Processing Record 50 of Set 1 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 1 of Set 2 | nelson bay
# Processing Record 2 of Set 2 | constitucion
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | vila velha
# Processing Record 5 of Set 2 | phayao
# Processing Record 6 of Set 2 | kununurra
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | rawson
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | straumen
# Processing Record 11 of Set 2 | longhua
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | port macquarie
# Processing Record 14 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | husavik
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | thompson
# Processing Record 19 of Set 2 | kirakira
# Processing Record 20 of Set 2 | amapa
# Processing Record 21 of Set 2 | warmbad
# Processing Record 22 of Set 2 | warri
# Processing Record 23 of Set 2 | margate
# Processing Record 24 of Set 2 | ostrovnoy
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | bambous virieux
# Processing Record 28 of Set 2 | rio gallegos
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | patea
# Processing Record 31 of Set 2 | alofi
# Processing Record 32 of Set 2 | vytegra
# Processing Record 33 of Set 2 | xuanhua
# Processing Record 34 of Set 2 | san carlos de bariloche
# Processing Record 35 of Set 2 | olinda
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | samarai
# Processing Record 38 of Set 2 | khandbari
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | bluff
# Processing Record 41 of Set 2 | lata
# Processing Record 42 of Set 2 | nanortalik
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | pevek
# Processing Record 45 of Set 2 | mpwapwa
# Processing Record 46 of Set 2 | mwanza
# Processing Record 47 of Set 2 | terekli-mekteb
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | chulman
# Processing Record 50 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 3 | vuktyl
# Processing Record 3 of Set 3 | paradise
# Processing Record 4 of Set 3 | ancud
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | gravdal
# Processing Record 7 of Set 3 | lorengau
# Processing Record 8 of Set 3 | esperance
# Processing Record 9 of Set 3 | mount isa
# Processing Record 10 of Set 3 | hounde
# Processing Record 11 of Set 3 | itarema
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | miri
# Processing Record 14 of Set 3 | grand baie
# Processing Record 15 of Set 3 | lagoa
# Processing Record 16 of Set 3 | port-gentil
# Processing Record 17 of Set 3 | chicama
# Processing Record 18 of Set 3 | barra do bugres
# Processing Record 19 of Set 3 | manta
# Processing Record 20 of Set 3 | tessalit
# Processing Record 21 of Set 3 | olafsvik
# Processing Record 22 of Set 3 | hobart
# Processing Record 23 of Set 3 | avera
# Processing Record 24 of Set 3 | kavaratti
# Processing Record 25 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 3 | muroto
# Processing Record 27 of Set 3 | san cristobal
# Processing Record 28 of Set 3 | nhulunbuy
# Processing Record 29 of Set 3 | cortez
# Processing Record 30 of Set 3 | hualmay
# Processing Record 31 of Set 3 | sindand
# City not found. Skipping...
# Processing Record 32 of Set 3 | sri aman
# Processing Record 33 of Set 3 | pangai
# Processing Record 34 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | kudahuvadhoo
# Processing Record 37 of Set 3 | dikson
# Processing Record 38 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 3 | bengkulu
# Processing Record 41 of Set 3 | piracanjuba
# Processing Record 42 of Set 3 | atar
# Processing Record 43 of Set 3 | cherskiy
# Processing Record 44 of Set 3 | wad madani
# Processing Record 45 of Set 3 | santa maria
# Processing Record 46 of Set 3 | vanimo
# Processing Record 47 of Set 3 | mackenzie
# Processing Record 48 of Set 3 | grindavik
# Processing Record 49 of Set 3 | puerto madryn
# Processing Record 50 of Set 3 | te anau
# Processing Record 1 of Set 4 | batemans bay
# Processing Record 2 of Set 4 | ambatofinandrahana
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | torbay
# Processing Record 5 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 6 of Set 4 | birao
# Processing Record 7 of Set 4 | nampula
# Processing Record 8 of Set 4 | hilo
# Processing Record 9 of Set 4 | mayo
# Processing Record 10 of Set 4 | kambove
# Processing Record 11 of Set 4 | port lincoln
# Processing Record 12 of Set 4 | ixtapa
# Processing Record 13 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 4 | hovd
# Processing Record 15 of Set 4 | isangel
# Processing Record 16 of Set 4 | jamestown
# Processing Record 17 of Set 4 | odessa
# Processing Record 18 of Set 4 | tuktoyaktuk
# Processing Record 19 of Set 4 | lavrentiya
# Processing Record 20 of Set 4 | rio grande
# Processing Record 21 of Set 4 | lillesand
# Processing Record 22 of Set 4 | vanavara
# Processing Record 23 of Set 4 | mar del plata
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | ukiah
# Processing Record 26 of Set 4 | lebu
# Processing Record 27 of Set 4 | pampierstad
# Processing Record 28 of Set 4 | hambantota
# Processing Record 29 of Set 4 | bourail
# Processing Record 30 of Set 4 | katsuura
# Processing Record 31 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 4 | vernon
# Processing Record 33 of Set 4 | dzhalil
# Processing Record 34 of Set 4 | portland
# Processing Record 35 of Set 4 | santa isabel do rio negro
# Processing Record 36 of Set 4 | port hedland
# Processing Record 37 of Set 4 | faridan
# City not found. Skipping...
# Processing Record 38 of Set 4 | columbia
# Processing Record 39 of Set 4 | georgetown
# Processing Record 40 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 4 | sinnai
# Processing Record 42 of Set 4 | surt
# Processing Record 43 of Set 4 | victoria
# Processing Record 44 of Set 4 | iqaluit
# Processing Record 45 of Set 4 | dabakala
# Processing Record 46 of Set 4 | bilibino
# Processing Record 47 of Set 4 | gilgit
# Processing Record 48 of Set 4 | mount gambier
# Processing Record 49 of Set 4 | ballina
# Processing Record 50 of Set 4 | ust-tsilma
# Processing Record 1 of Set 5 | urusha
# Processing Record 2 of Set 5 | cabedelo
# Processing Record 3 of Set 5 | kanniyakumari
# Processing Record 4 of Set 5 | clyde river
# Processing Record 5 of Set 5 | new norfolk
# Processing Record 6 of Set 5 | gimli
# Processing Record 7 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 5 | san bartolome de tirajana
# Processing Record 9 of Set 5 | sao domingos do maranhao
# Processing Record 10 of Set 5 | rajakhera
# Processing Record 11 of Set 5 | port hardy
# Processing Record 12 of Set 5 | new waterford
# Processing Record 13 of Set 5 | sao jose da coroa grande
# Processing Record 14 of Set 5 | yerbogachen
# Processing Record 15 of Set 5 | lewistown
# Processing Record 16 of Set 5 | adrar
# Processing Record 17 of Set 5 | niquero
# Processing Record 18 of Set 5 | victor harbor
# Processing Record 19 of Set 5 | mahibadhoo
# Processing Record 20 of Set 5 | narsaq
# Processing Record 21 of Set 5 | kaitangata
# Processing Record 22 of Set 5 | lagunas
# Processing Record 23 of Set 5 | bambanglipuro
# Processing Record 24 of Set 5 | pangnirtung
# Processing Record 25 of Set 5 | mega
# Processing Record 26 of Set 5 | port alfred
# Processing Record 27 of Set 5 | cidreira
# Processing Record 28 of Set 5 | san vicente
# Processing Record 29 of Set 5 | la tuque
# Processing Record 30 of Set 5 | vardo
# Processing Record 31 of Set 5 | chumikan
# Processing Record 32 of Set 5 | sao borja
# Processing Record 33 of Set 5 | fengcheng
# Processing Record 34 of Set 5 | flin flon
# Processing Record 35 of Set 5 | osorno
# Processing Record 36 of Set 5 | luderitz
# Processing Record 37 of Set 5 | dao
# Processing Record 38 of Set 5 | hami
# Processing Record 39 of Set 5 | ucluelet
# Processing Record 40 of Set 5 | fort nelson
# Processing Record 41 of Set 5 | whitianga
# Processing Record 42 of Set 5 | aktash
# Processing Record 43 of Set 5 | saskylakh
# Processing Record 44 of Set 5 | kabo
# Processing Record 45 of Set 5 | saint-pierre
# Processing Record 46 of Set 5 | bulgan
# Processing Record 47 of Set 5 | severo-kurilsk
# Processing Record 48 of Set 5 | babu
# Processing Record 49 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 50 of Set 5 | magdagachi
# Processing Record 1 of Set 6 | talcahuano
# Processing Record 2 of Set 6 | sao joao da barra
# Processing Record 3 of Set 6 | taoudenni
# Processing Record 4 of Set 6 | khatanga
# Processing Record 5 of Set 6 | hamilton
# Processing Record 6 of Set 6 | saint anthony
# Processing Record 7 of Set 6 | dakar
# Processing Record 8 of Set 6 | hithadhoo
# Processing Record 9 of Set 6 | santa cruz
# Processing Record 10 of Set 6 | lompoc
# Processing Record 11 of Set 6 | kotma
# Processing Record 12 of Set 6 | deputatskiy
# Processing Record 13 of Set 6 | gitega
# Processing Record 14 of Set 6 | mocuba
# Processing Record 15 of Set 6 | vila
# Processing Record 16 of Set 6 | sao felix do xingu
# Processing Record 17 of Set 6 | puro
# Processing Record 18 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 19 of Set 6 | cayenne
# Processing Record 20 of Set 6 | vao
# Processing Record 21 of Set 6 | labuhan
# Processing Record 22 of Set 6 | vagay
# Processing Record 23 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 6 | kenora
# Processing Record 25 of Set 6 | shizunai
# Processing Record 26 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 6 | port blair
# Processing Record 28 of Set 6 | xifeng
# Processing Record 29 of Set 6 | krasnyy yar
# Processing Record 30 of Set 6 | ejea de los caballeros
# Processing Record 31 of Set 6 | birjand
# Processing Record 32 of Set 6 | berlevag
# Processing Record 33 of Set 6 | sitka
# Processing Record 34 of Set 6 | faya
# Processing Record 35 of Set 6 | rovaniemi
# Processing Record 36 of Set 6 | acapulco
# Processing Record 37 of Set 6 | saint-augustin
# Processing Record 38 of Set 6 | sur
# Processing Record 39 of Set 6 | araouane
# Processing Record 40 of Set 6 | padang
# Processing Record 41 of Set 6 | anadyr
# Processing Record 42 of Set 6 | peniche
# Processing Record 43 of Set 6 | narowal
# Processing Record 44 of Set 6 | kathu
# Processing Record 45 of Set 6 | usakos
# Processing Record 46 of Set 6 | northam
# Processing Record 47 of Set 6 | likhoy
# Processing Record 48 of Set 6 | kosonsoy
# Processing Record 49 of Set 6 | kitui
# Processing Record 50 of Set 6 | zlobin
# Processing Record 1 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 7 | bubaque
# Processing Record 3 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 7 | sungaipenuh
# Processing Record 5 of Set 7 | kirksville
# Processing Record 6 of Set 7 | hervey bay
# Processing Record 7 of Set 7 | ozernovskiy
# Processing Record 8 of Set 7 | maiduguri
# Processing Record 9 of Set 7 | takoradi
# Processing Record 10 of Set 7 | natal
# Processing Record 11 of Set 7 | tanout
# Processing Record 12 of Set 7 | yar-sale
# Processing Record 13 of Set 7 | broken hill
# Processing Record 14 of Set 7 | kuznechikha
# Processing Record 15 of Set 7 | kars
# Processing Record 16 of Set 7 | mao
# Processing Record 17 of Set 7 | puri
# Processing Record 18 of Set 7 | marzuq
# Processing Record 19 of Set 7 | plainview
# Processing Record 20 of Set 7 | obsharovka
# Processing Record 21 of Set 7 | klaksvik
# Processing Record 22 of Set 7 | waipawa
# Processing Record 23 of Set 7 | malampaka
# Processing Record 24 of Set 7 | sasaram
# Processing Record 25 of Set 7 | tucurui
# Processing Record 26 of Set 7 | tuatapere
# Processing Record 27 of Set 7 | sinnamary
# Processing Record 28 of Set 7 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 29 of Set 7 | yumen
# Processing Record 30 of Set 7 | fortuna
# Processing Record 31 of Set 7 | gournai
# City not found. Skipping...
# Processing Record 32 of Set 7 | los llanos de aridane
# Processing Record 33 of Set 7 | bandarbeyla
# Processing Record 34 of Set 7 | stornoway
# Processing Record 35 of Set 7 | aksu
# Processing Record 36 of Set 7 | pinheiro machado
# Processing Record 37 of Set 7 | santa rosa
# Processing Record 38 of Set 7 | belaya gora
# Processing Record 39 of Set 7 | acari
# Processing Record 40 of Set 7 | quang ngai
# Processing Record 41 of Set 7 | podolsk
# Processing Record 42 of Set 7 | jalu
# Processing Record 43 of Set 7 | chokurdakh
# Processing Record 44 of Set 7 | hastings
# Processing Record 45 of Set 7 | dudinka
# Processing Record 46 of Set 7 | sydney
# Processing Record 47 of Set 7 | shimoda
# Processing Record 48 of Set 7 | freetown
# Processing Record 49 of Set 7 | guerrero negro
# Processing Record 50 of Set 7 | kavieng
# Processing Record 1 of Set 8 | provideniya
# Processing Record 2 of Set 8 | saint-jean-port-joli
# Processing Record 3 of Set 8 | axim
# Processing Record 4 of Set 8 | brasilia
# Processing Record 5 of Set 8 | washington
# Processing Record 6 of Set 8 | airai
# Processing Record 7 of Set 8 | aquiraz
# Processing Record 8 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 8 | srednekolymsk
# Processing Record 10 of Set 8 | kimbe
# Processing Record 11 of Set 8 | ardakan
# Processing Record 12 of Set 8 | pueblo
# Processing Record 13 of Set 8 | concordia
# Processing Record 14 of Set 8 | bani walid
# Processing Record 15 of Set 8 | treinta y tres
# Processing Record 16 of Set 8 | ndioum
# Processing Record 17 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 18 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 8 | kano
# Processing Record 20 of Set 8 | tarbert
# Processing Record 21 of Set 8 | najran
# Processing Record 22 of Set 8 | praia
# Processing Record 23 of Set 8 | oropesa
# Processing Record 24 of Set 8 | christchurch
# Processing Record 25 of Set 8 | altamont
# Processing Record 26 of Set 8 | nome
# Processing Record 27 of Set 8 | alugan
# Processing Record 28 of Set 8 | rafaela
# Processing Record 29 of Set 8 | vestmannaeyjar
# Processing Record 30 of Set 8 | isla vista
# Processing Record 31 of Set 8 | yarada
# Processing Record 32 of Set 8 | debre tabor
# Processing Record 33 of Set 8 | bow island
# Processing Record 34 of Set 8 | kingsville
# Processing Record 35 of Set 8 | lodwar
# Processing Record 36 of Set 8 | omboue
# Processing Record 37 of Set 8 | inongo
# Processing Record 38 of Set 8 | fukue
# Processing Record 39 of Set 8 | rocha
# Processing Record 40 of Set 8 | kieta
# Processing Record 41 of Set 8 | berezovka
# Processing Record 42 of Set 8 | plover
# Processing Record 43 of Set 8 | vostok
# Processing Record 44 of Set 8 | kupang
# Processing Record 45 of Set 8 | bossangoa
# Processing Record 46 of Set 8 | moiyabana
# City not found. Skipping...
# Processing Record 47 of Set 8 | zhanaozen
# Processing Record 48 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 49 of Set 8 | laurel
# Processing Record 50 of Set 8 | chuy
# Processing Record 1 of Set 9 | severo-yeniseyskiy
# Processing Record 2 of Set 9 | ponta delgada
# Processing Record 3 of Set 9 | kloulklubed
# Processing Record 4 of Set 9 | geraldton
# Processing Record 5 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 6 of Set 9 | leh
# Processing Record 7 of Set 9 | baracoa
# Processing Record 8 of Set 9 | lasa
# Processing Record 9 of Set 9 | egvekinot
# Processing Record 10 of Set 9 | zhumadian
# Processing Record 11 of Set 9 | eirunepe
# Processing Record 12 of Set 9 | riverton
# Processing Record 13 of Set 9 | wuwei
# Processing Record 14 of Set 9 | leningradskiy
# Processing Record 15 of Set 9 | kanye
# Processing Record 16 of Set 9 | sungairaya
# Processing Record 17 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 9 | conceicao da barra
# Processing Record 19 of Set 9 | ilulissat
# Processing Record 20 of Set 9 | hofn
# Processing Record 21 of Set 9 | alice
# Processing Record 22 of Set 9 | price
# Processing Record 23 of Set 9 | verkhnyaya inta
# Processing Record 24 of Set 9 | iskateley
# Processing Record 25 of Set 9 | halifax
# Processing Record 26 of Set 9 | vladyslavivka
# Processing Record 27 of Set 9 | grand gaube
# Processing Record 28 of Set 9 | matara
# Processing Record 29 of Set 9 | freeport
# Processing Record 30 of Set 9 | aklavik
# Processing Record 31 of Set 9 | ippy
# Processing Record 32 of Set 9 | inverell
# Processing Record 33 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 9 | raton
# Processing Record 35 of Set 9 | sola
# Processing Record 36 of Set 9 | jambi
# Processing Record 37 of Set 9 | yulara
# Processing Record 38 of Set 9 | haines junction
# Processing Record 39 of Set 9 | cockburn town
# Processing Record 40 of Set 9 | hobyo
# Processing Record 41 of Set 9 | upernavik
# Processing Record 42 of Set 9 | bapatla
# Processing Record 43 of Set 9 | aden
# Processing Record 44 of Set 9 | sechura
# Processing Record 45 of Set 9 | saldanha
# Processing Record 46 of Set 9 | bad munstereifel
# Processing Record 47 of Set 9 | san rafael
# Processing Record 48 of Set 9 | koulamoutou
# Processing Record 49 of Set 9 | san luis
# Processing Record 50 of Set 9 | maragogi
# Processing Record 1 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 10 | sangar
# Processing Record 3 of Set 10 | wajid
# Processing Record 4 of Set 10 | buala
# Processing Record 5 of Set 10 | kuhdasht
# Processing Record 6 of Set 10 | bartica
# Processing Record 7 of Set 10 | bereda
# Processing Record 8 of Set 10 | tanabe
# Processing Record 9 of Set 10 | kattivakkam
# Processing Record 10 of Set 10 | makakilo city
# Processing Record 11 of Set 10 | burns lake
# Processing Record 12 of Set 10 | yermakovskoye
# Processing Record 13 of Set 10 | staraya poltavka
# Processing Record 14 of Set 10 | caravelas
# Processing Record 15 of Set 10 | talnakh
# Processing Record 16 of Set 10 | rosarito
# Processing Record 17 of Set 10 | mehran
# Processing Record 18 of Set 10 | san joaquin
# Processing Record 19 of Set 10 | chernyshevskiy
# Processing Record 20 of Set 10 | borba
# Processing Record 21 of Set 10 | poptun
# Processing Record 22 of Set 10 | chowchilla
# Processing Record 23 of Set 10 | rundu
# Processing Record 24 of Set 10 | nayagarh
# Processing Record 25 of Set 10 | kabinda
# Processing Record 26 of Set 10 | council bluffs
# Processing Record 27 of Set 10 | cabo san lucas
# Processing Record 28 of Set 10 | maitum
# Processing Record 29 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 10 | san patricio
# Processing Record 31 of Set 10 | honningsvag
# Processing Record 32 of Set 10 | nipawin
# Processing Record 33 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 10 | aguililla
# Processing Record 35 of Set 10 | miami
# Processing Record 36 of Set 10 | kankaanpaa
# Processing Record 37 of Set 10 | huarmey
# Processing Record 38 of Set 10 | brigantine
# Processing Record 39 of Set 10 | barentu
# Processing Record 40 of Set 10 | villaviciosa
# Processing Record 41 of Set 10 | mount pleasant
# Processing Record 42 of Set 10 | sisimiut
# Processing Record 43 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 10 | bad reichenhall
# Processing Record 45 of Set 10 | tianpeng
# Processing Record 46 of Set 10 | la uribe
# City not found. Skipping...
# Processing Record 47 of Set 10 | mazara del vallo
# Processing Record 48 of Set 10 | burica
# City not found. Skipping...
# Processing Record 49 of Set 10 | youhao
# Processing Record 50 of Set 10 | vetluga
# Processing Record 1 of Set 11 | saint-joseph
# Processing Record 2 of Set 11 | shenjiamen
# Processing Record 3 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 11 | nago
# Processing Record 5 of Set 11 | sept-iles
# Processing Record 6 of Set 11 | mangan
# Processing Record 7 of Set 11 | nishihara
# Processing Record 8 of Set 11 | marsabit
# Processing Record 9 of Set 11 | gao
# Processing Record 10 of Set 11 | arman
# Processing Record 11 of Set 11 | barranca
# Processing Record 12 of Set 11 | aykhal
# Processing Record 13 of Set 11 | matamoros
# Processing Record 14 of Set 11 | urumqi
# Processing Record 15 of Set 11 | nalut
# Processing Record 16 of Set 11 | burnie
# Processing Record 17 of Set 11 | sayyan
# Processing Record 18 of Set 11 | roma
# Processing Record 19 of Set 11 | mindelo
# Processing Record 20 of Set 11 | bardiyah
# Processing Record 21 of Set 11 | laguna
# Processing Record 22 of Set 11 | badaojiang
# City not found. Skipping...
# Processing Record 23 of Set 11 | umea
# Processing Record 24 of Set 11 | cottbus
# Processing Record 25 of Set 11 | bemidji
# Processing Record 26 of Set 11 | chuzhou
# Processing Record 27 of Set 11 | beringovskiy
# Processing Record 28 of Set 11 | redmond
# Processing Record 29 of Set 11 | port augusta
# Processing Record 30 of Set 11 | atchison
# Processing Record 31 of Set 11 | burgos
# Processing Record 32 of Set 11 | marau
# Processing Record 33 of Set 11 | douglas
# Processing Record 34 of Set 11 | paamiut
# Processing Record 35 of Set 11 | maniitsoq
# Processing Record 36 of Set 11 | marrakesh
# Processing Record 37 of Set 11 | kiunga
# Processing Record 38 of Set 11 | champerico
# Processing Record 39 of Set 11 | guider
# Processing Record 40 of Set 11 | zemio
# Processing Record 41 of Set 11 | thinadhoo
# Processing Record 42 of Set 11 | biak
# Processing Record 43 of Set 11 | trinidad
# Processing Record 44 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 11 | nouakchott
# Processing Record 46 of Set 11 | nurota
# Processing Record 47 of Set 11 | tabou
# Processing Record 48 of Set 11 | kargasok
# Processing Record 49 of Set 11 | bitung
# Processing Record 50 of Set 11 | nerchinskiy zavod
# Processing Record 1 of Set 12 | hauterive
# Processing Record 2 of Set 12 | paramonga
# Processing Record 3 of Set 12 | synya
# Processing Record 4 of Set 12 | kedgwick
# Processing Record 5 of Set 12 | biskamzha
# Processing Record 6 of Set 12 | sobolevo
# Processing Record 7 of Set 12 | tazovskiy
# Processing Record 8 of Set 12 | kyren
# Processing Record 9 of Set 12 | narrabri
# Processing Record 10 of Set 12 | amga
# Processing Record 11 of Set 12 | vrangel
# Processing Record 12 of Set 12 | blairmore
# Processing Record 13 of Set 12 | dera bugti
# Processing Record 14 of Set 12 | tartus
# Processing Record 15 of Set 12 | jiuquan
# Processing Record 16 of Set 12 | tupik
# Processing Record 17 of Set 12 | umm kaddadah
# Processing Record 18 of Set 12 | merauke
# Processing Record 19 of Set 12 | arcata
# Processing Record 20 of Set 12 | gongzhuling
# Processing Record 21 of Set 12 | xiuyan
# Processing Record 22 of Set 12 | kayes
# Processing Record 23 of Set 12 | korla
# Processing Record 24 of Set 12 | tome
# Processing Record 25 of Set 12 | esso
# Processing Record 26 of Set 12 | denpasar
# Processing Record 27 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 12 | careva cuprija
# Processing Record 29 of Set 12 | xaltianguis
# Processing Record 30 of Set 12 | portree
# Processing Record 31 of Set 12 | esmeraldas
# Processing Record 32 of Set 12 | villazon
# Processing Record 33 of Set 12 | yanam
# Processing Record 34 of Set 12 | suez
# Processing Record 35 of Set 12 | mackay
# Processing Record 36 of Set 12 | kokopo
# Processing Record 37 of Set 12 | itoman
# Processing Record 38 of Set 12 | zhigansk
# Processing Record 39 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 12 | west bay
# Processing Record 41 of Set 12 | ulety
# Processing Record 42 of Set 12 | jacksonville
# Processing Record 43 of Set 12 | eyl
# Processing Record 44 of Set 12 | abu samrah
# Processing Record 45 of Set 12 | riyadh
# Processing Record 46 of Set 12 | vila franca do campo
# Processing Record 47 of Set 12 | asfi
# Processing Record 48 of Set 12 | roald
# Processing Record 49 of Set 12 | esil
# Processing Record 50 of Set 12 | bamiantong
# Processing Record 1 of Set 13 | brandfort
# Processing Record 2 of Set 13 | port orange
# Processing Record 3 of Set 13 | arlit
# Processing Record 4 of Set 13 | samana
# Processing Record 5 of Set 13 | jaciara
# Processing Record 6 of Set 13 | walvis bay
# Processing Record 7 of Set 13 | flinders
# Processing Record 8 of Set 13 | bavleny
# Processing Record 9 of Set 13 | bowen
# Processing Record 10 of Set 13 | college
# Processing Record 11 of Set 13 | svetlyy
# Processing Record 12 of Set 13 | normandin
# Processing Record 13 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 14 of Set 13 | palimbang
# Processing Record 15 of Set 13 | bako
# Processing Record 16 of Set 13 | bilma
# Processing Record 17 of Set 13 | chapais
# Processing Record 18 of Set 13 | north platte
# Processing Record 19 of Set 13 | camacha
# Processing Record 20 of Set 13 | puksoozero
# Processing Record 21 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 22 of Set 13 | awjilah
# Processing Record 23 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 13 | jishui
# Processing Record 25 of Set 13 | jiblah
# Processing Record 26 of Set 13 | honghu
# Processing Record 27 of Set 13 | strezhevoy
# Processing Record 28 of Set 13 | nevel
# Processing Record 29 of Set 13 | obihiro
# Processing Record 30 of Set 13 | mus
# Processing Record 31 of Set 13 | santiago de cuba
# Processing Record 32 of Set 13 | humaita
# Processing Record 33 of Set 13 | calama
# Processing Record 34 of Set 13 | puerto rico
# Processing Record 35 of Set 13 | joplin
# Processing Record 36 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 13 | yenagoa
# Processing Record 38 of Set 13 | payo
# Processing Record 39 of Set 13 | andenes
# Processing Record 40 of Set 13 | sibolga
# Processing Record 41 of Set 13 | suraabad
# Processing Record 42 of Set 13 | cuamba
# Processing Record 43 of Set 13 | wanaka
# Processing Record 44 of Set 13 | martapura
# Processing Record 45 of Set 13 | makubetsu
# Processing Record 46 of Set 13 | monterey
# Processing Record 47 of Set 13 | bundaberg
# Processing Record 48 of Set 13 | mezen
# Processing Record 49 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 13 | acajutla
# Processing Record 1 of Set 14 | broome
# Processing Record 2 of Set 14 | saulia
# Processing Record 3 of Set 14 | soderhamn
# Processing Record 4 of Set 14 | cape canaveral
# Processing Record 5 of Set 14 | taman
# Processing Record 6 of Set 14 | coari
# Processing Record 7 of Set 14 | guymon
# Processing Record 8 of Set 14 | mama
# Processing Record 9 of Set 14 | langelsheim
# Processing Record 10 of Set 14 | atasu
# Processing Record 11 of Set 14 | calamar
# Processing Record 12 of Set 14 | tura
# Processing Record 13 of Set 14 | kamenka
# Processing Record 14 of Set 14 | san jose
# Processing Record 15 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 14 | tilichiki
# Processing Record 17 of Set 14 | san-pedro
# Processing Record 18 of Set 14 | saint-georges
# Processing Record 19 of Set 14 | gizo
# Processing Record 20 of Set 14 | great yarmouth
# Processing Record 21 of Set 14 | soyo
# Processing Record 22 of Set 14 | carlsbad
# Processing Record 23 of Set 14 | amazar
# Processing Record 24 of Set 14 | khani
# Processing Record 25 of Set 14 | pendleton
# Processing Record 26 of Set 14 | prachuap khiri khan
# Processing Record 27 of Set 14 | iracoubo
# Processing Record 28 of Set 14 | wanning
# Processing Record 29 of Set 14 | siyabuswa
# Processing Record 30 of Set 14 | beinamar
# Processing Record 31 of Set 14 | vallenar
# Processing Record 32 of Set 14 | comodoro rivadavia
# Processing Record 33 of Set 14 | kjollefjord
# Processing Record 34 of Set 14 | fayaoue
# Processing Record 35 of Set 14 | skala
# Processing Record 36 of Set 14 | moree
# Processing Record 37 of Set 14 | hirara
# Processing Record 38 of Set 14 | lockport
# Processing Record 39 of Set 14 | palmer
# Processing Record 40 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 14 | lake charles
# Processing Record 42 of Set 14 | ayan
# Processing Record 43 of Set 14 | fresnillo
# Processing Record 44 of Set 14 | marion
# Processing Record 45 of Set 14 | tacuarembo
# Processing Record 46 of Set 14 | pisco
# Processing Record 47 of Set 14 | cumberland
# Processing Record 48 of Set 14 | kisangani
# Processing Record 49 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 14 | fairbanks
# Processing Record 1 of Set 15 | bismarck
# Processing Record 2 of Set 15 | maarianhamina
# Processing Record 3 of Set 15 | shingu
# Processing Record 4 of Set 15 | aksum
# Processing Record 5 of Set 15 | lubango
# Processing Record 6 of Set 15 | camana
# Processing Record 7 of Set 15 | rock sound
# Processing Record 8 of Set 15 | port antonio
# Processing Record 9 of Set 15 | aberdeen
# Processing Record 10 of Set 15 | paracuru
# Processing Record 11 of Set 15 | maceio
# Processing Record 12 of Set 15 | sarh
# Processing Record 13 of Set 15 | rawicz
# Processing Record 14 of Set 15 | lahat
# Processing Record 15 of Set 15 | zorritos
# Processing Record 16 of Set 15 | jiaohe
# Processing Record 17 of Set 15 | tukan
# Processing Record 18 of Set 15 | tintigny
# Processing Record 19 of Set 15 | viedma
# Processing Record 20 of Set 15 | cabinda
# Processing Record 21 of Set 15 | bacolod
# Processing Record 22 of Set 15 | myaundzha
# Processing Record 23 of Set 15 | fallon
# Processing Record 24 of Set 15 | kalmunai
# Processing Record 25 of Set 15 | qaqortoq
# Processing Record 26 of Set 15 | novyy urengoy
# Processing Record 27 of Set 15 | hilton head island
# Processing Record 28 of Set 15 | muros
# Processing Record 29 of Set 15 | ambulu
# Processing Record 30 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 15 | superior
# Processing Record 33 of Set 15 | stephenville crossing
# Processing Record 34 of Set 15 | waiuku
# Processing Record 35 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 36 of Set 15 | duluth
# Processing Record 37 of Set 15 | mixtepec
# City not found. Skipping...
# Processing Record 38 of Set 15 | bogorodskoye
# Processing Record 39 of Set 15 | iquique
# Processing Record 40 of Set 15 | daru
# Processing Record 41 of Set 15 | beloha
# Processing Record 42 of Set 15 | singaparna
# Processing Record 43 of Set 15 | buraydah
# Processing Record 44 of Set 15 | naze
# Processing Record 45 of Set 15 | mvomero
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hermanus -34.4187   19.2345     71.80        62           0
# 1           Touros  -5.1989  -35.4608     75.65        75           1
# 2            Kapaa  22.0752 -159.3190     76.98        92          40
# 3          Rikitea -23.1203 -134.9692     73.38        69          10
# 4            Aswan  24.0934   32.9070    100.47        16           0
# 5  Arraial Do Cabo -22.9661  -42.0278     66.06        94          20
# 6   Ribeira Grande  38.5167  -28.7000     70.20       100          75
# 7     Punta Arenas -53.1500  -70.9167     26.71        93           0
# 8          Mumford   5.2618   -0.7590     76.96        85          96
# 9           Qunduz  36.7290   68.8570     80.82        14           0
#
#    Wind Speed Country Current Description                 Date
# 0        7.72      ZA           clear sky  2022-10-02 09:15:13
# 1       13.58      BR           clear sky  2022-10-02 09:15:14
# 2        4.61      US          light rain  2022-10-02 09:15:14
# 3       10.27      PF           clear sky  2022-10-02 09:23:44
# 4        9.19      EG           clear sky  2022-10-02 09:15:15
# 5        2.30      BR          few clouds  2022-10-02 09:15:16
# 6       20.71      PT         shower rain  2022-10-02 09:23:45
# 7        6.91      CL           clear sky  2022-10-02 09:23:45
# 8        4.09      GH          light rain  2022-10-02 09:23:46
# 9        9.75      AF           clear sky  2022-10-02 09:23:46

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_col_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_col_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hermanus      ZA -34.4187   19.2345     71.80        62           0
# 1           Touros      BR  -5.1989  -35.4608     75.65        75           1
# 2            Kapaa      US  22.0752 -159.3190     76.98        92          40
# 3          Rikitea      PF -23.1203 -134.9692     73.38        69          10
# 4            Aswan      EG  24.0934   32.9070    100.47        16           0
# 5  Arraial Do Cabo      BR -22.9661  -42.0278     66.06        94          20
# 6   Ribeira Grande      PT  38.5167  -28.7000     70.20       100          75
# 7     Punta Arenas      CL -53.1500  -70.9167     26.71        93           0
# 8          Mumford      GH   5.2618   -0.7590     76.96        85          96
# 9           Qunduz      AF  36.7290   68.8570     80.82        14           0
#
#    Wind Speed Current Description
# 0        7.72           clear sky
# 1       13.58           clear sky
# 2        4.61          light rain
# 3       10.27           clear sky
# 4        9.19           clear sky
# 5        2.30          few clouds
# 6       20.71         shower rain
# 7        6.91           clear sky
# 8        4.09          light rain
# 9        9.75           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
